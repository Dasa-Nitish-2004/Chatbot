# %%
from langchain_google_genai import GoogleGenerativeAIEmbeddings
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import ChatPromptTemplate
llm = ChatGoogleGenerativeAI(
    api_key="AIzaSyDOTWIDe1OkNOJv01XC8OU5jQOB4xsA2dw",
    model="gemini-1.5-pro",
    temperature=0,
    max_tokens=None,
    timeout=None,
    max_retries=2,
    # other params...
)

embeddings = GoogleGenerativeAIEmbeddings(model="models/embedding-001",google_api_key="AIzaSyDOTWIDe1OkNOJv01XC8OU5jQOB4xsA2dw")
len(embeddings.embed_query(" "))
# Out:
# 768

# %%
from langchain_community.document_loaders.csv_loader import CSVLoader
# from langchain.document_loaders.csv_loader import CSVLoader
loader =CSVLoader(file_path="D:\\nitish\\python\\ml\\codebasics\\chatbot\\chatbot2\\Lib\\q and a\\JNTUH_Student_Services_FAQ.csv")
data = loader.load()

# %%
from langchain_community.embeddings import FakeEmbeddings
from langchain.embeddings import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS
# # from sentence_transformers import SentenceTransformer
from langchain_community.embeddings import FakeEmbeddings
# embeddings = FakeEmbeddings(size=1352)
# embedding_model = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")

# embeddings = FakeEmbeddings(size=1352)
faiss_index = FAISS.from_documents(documents=data, embedding=embeddings)

# %%
# from langchain.embeddings import HuggingFaceEmbeddings
# from langchain_community.vectorstores import FAISS
# from sentence_transformers import SentenceTransformer

# embedding_model = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")

# faiss_index = FAISS.from_documents(documents=data, embedding=embedding_model)

# %%
    def populateResult(que):
        ret = faiss_index.as_retriever()
        rdocs = ret.get_relevant_documents(que)
        print("More Suitable question")
        result = []

        

        for doc in rdocs:
            prompt = doc.page_content.split('?')[0].replace('prompt: ', '')
            response = doc.page_content.split('?')[1].replace('response: ', '')
            result.append({"question":prompt,"answer":response})
            # print(f"Question: {prompt}")
            # print(f"Answer: {response}\n")
        return result

# %%
prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            "You are a helpful assistant that combines the following question answers to generate single question and answer {question_answer}.",
        ),
        ("human", "{actual_question}"),
    ]
)
chain = prompt | llm

def AskQuestion():
    que = input("Enter Query : ")
    result = populateResult(que)
    return {
        "AI" : chain.invoke(
        {
            "question_answer": result,
            "actual_question": que,
        }
    ).content,
        "related_Doc": result
        }
print(AskQuestion())
# Out:
# More Suitable question
# {'AI': '**What should I do if my payment failed, or if the amount was deducted multiple times?**\n\nDo not pay the fee multiple times for one request. Each transaction is treated as a separate request, and the service will be provided for each successful transaction. If your amount was deducted but you received a "transaction failed" or "session expired" message, do not pay again. The application status will be updated in the \'Track Application\' menu within 2 working days of your transaction.  Refunds are not provided, as the processing of transcripts/certificates begins soon after a successful transaction.\n', 'related_Doc': [{'question': 'ï»¿What should we do if amount is deducted many times (multiple payments)', 'answer': "\nUsers should not pay fee multiple times for one request. Because every transaction will take as request and service will be provided for every transaction. If your amount were deducted from your account in any transaction and were failed / session expired message, You are advised not to pay once again. The application status will be updated in 'Track Application' menu within 2 working days of your transaction."}, {'question': 'ï»¿What to do if we get a message saying transaction failed / session expired', 'answer': "\nIf your amount were deducted from your account in any transaction and got failed / session expired message, You are advised not to pay once again. The application status will be updated in 'Track Application' menu within 2 working days of your transaction."}, {'question': 'ï»¿What is the procedure for refund', 'answer': '\nNo refund will be entertained. Every transaction will be serviced by request transcripts / certificates. Because, the process of your requested transcripts/ certificates printing is started with in few time, printed transcripts / certificates can'}, {'question': 'ï»¿When I tried to apply for a online service in online student service portal, I am getting a response -invalid hall ticket number or data not available. Why', 'answer': '\nThe Candidates who passed their degree during or after the academic year mentioned below can only avail this service. B.Tech'}]}
